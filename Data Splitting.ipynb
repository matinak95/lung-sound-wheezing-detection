# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import librosa as lb
import os

# %%
def extractId(filename):
    return filename.split('_')[0]

# %%
data=pd.read_csv('/content/drive/My Drive/Lung_Project/csv_data/data.csv')
data.head()
# Out:
#    Start_time  End_Time  ...               File_Name                    Audio_Name
# 0       1.018     3.411  ...  107_2b4_Pr_mc_AKGC417L  107_2b4_Pr_mc_AKGC417L_0.wav
# 1       3.411     5.827  ...  107_2b4_Pr_mc_AKGC417L  107_2b4_Pr_mc_AKGC417L_1.wav
# 2       5.827     8.339  ...  107_2b4_Pr_mc_AKGC417L  107_2b4_Pr_mc_AKGC417L_2.wav
# 3       8.339    10.923  ...  107_2b4_Pr_mc_AKGC417L  107_2b4_Pr_mc_AKGC417L_3.wav
# 4      10.923    13.292  ...  107_2b4_Pr_mc_AKGC417L  107_2b4_Pr_mc_AKGC417L_4.wav
#
# [5 rows x 7 columns]

# %%
sns.countplot(data.Wheezing)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.model_selection import train_test_split
Xtrain,Xval,ytrain,yval=train_test_split(data,data.Wheezing,stratify=data.Wheezing,random_state=42,test_size=0.25)

# %%
Xtrain.Wheezing.value_counts()/Xtrain.shape[0]
# Out:
# 0    0.798183
# 1    0.201817
# Name: Wheezing, dtype: float64

# %%
Xval.Wheezing.value_counts()/Xval.shape[0]
# Out:
# 0    0.798261
# 1    0.201739
# Name: Wheezing, dtype: float64

# %%
Xtrain.to_csv('/content/drive/My Drive/Lung_Project/csv_data/train.csv')
Xval.to_csv('/content/drive/My Drive/Lung_Project/csv_data/val.csv')

# %%
Xtrain.shape
# Out:
# (5173, 7)

# %%
Xval.shape
# Out:
# (1725, 7)
